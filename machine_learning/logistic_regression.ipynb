# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('diabetes2.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X=df.iloc[:,0:8]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=5)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
lr=LogisticRegression()
clf=DecisionTreeClassifier()

# %%
lr.fit(X_train,y_train)
clf.fit(X_train,y_train)
# Out:
# C:\Users\nbhar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier()

# %%
y_pred=lr.predict(X_test)
Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print("accuracy of the lr:",accuracy_score(y_test,y_pred))
print("accuracy of the clf:",accuracy_score(y_test,Y_pred))
# Out:
# accuracy of the lr: 0.7857142857142857
# accuracy of the clf: 0.6948051948051948

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[87, 13],
#        [20, 34]])

# %%
lr.score(X_train,y_train)
# Out:
# 0.7850162866449512

# %%
lr.score(X_test,y_test)
# Out:
# 0.7857142857142857

# %%
lr.coef_
# Out:
# array([[ 1.32803304e-01,  3.19120277e-02, -2.04524657e-02,
#         -4.82339796e-03, -5.45468081e-04,  7.93567953e-02,
#          1.60034502e+00,  1.26533333e-02]])

# %%
lr.intercept_
# Out:
# array([-7.34599195])

# %%
from sklearn.metrics import recall_score,precision_score,f1_score

# %%
print("Precision - ",precision_score(y_test,y_pred))
print("Recall - ",recall_score(y_test,y_pred))
print("F1 score - ",f1_score(y_test,y_pred))
# Out:
# Precision -  0.723404255319149
# Recall -  0.6296296296296297
# F1 score -  0.6732673267326733

# %%
print("Precision - ",precision_score(y_test,Y_pred))
print("Recall - ",recall_score(y_test,Y_pred))
print("F1 score - ",f1_score(y_test,Y_pred))
# Out:
# Precision -  0.5614035087719298
# Recall -  0.5925925925925926
# F1 score -  0.5765765765765766

# %%
from sklearn import tree

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.6431839554398148, 0.9705882352941176, 'x[1] <= 154.5\ngini = 0.454\nsamples = 614\nvalue = [400, 214]'),
#  Text(0.3453956886574074, 0.9117647058823529, 'x[7] <= 28.5\ngini = 0.391\nsamples = 521\nvalue = [382, 139]'),
#  Text(0.49428982204861105, 0.9411764705882353, 'True  '),
#  Text(0.19126157407407407, 0.8529411764705882, 'x[5] <= 30.95\ngini = 0.251\nsamples = 278\nvalue = [237, 41]'),
#  Text(0.06018518518518518, 0.7941176470588235, 'x[0] <= 7.5\ngini = 0.092\nsamples = 144\nvalue = [137, 7]'),
#  Text(0.05092592592592592, 0.7352941176470589, 'x[1] <= 127.5\ngini = 0.08\nsamples = 143\nvalue = [137, 6]'),
#  Text(0.018518518518518517, 0.6764705882352942, 'x[6] <= 0.672\ngini = 0.016\nsamples = 121\nvalue = [120, 1]'),
#  Text(0.009259259259259259, 0.6176470588235294, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.027777777777777776, 0.6176470588235294, 'x[6] <= 0.686\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.018518518518518517, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.037037037037037035, 0.5588235294117647, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.08333333333333333, 0.6764705882352942, 'x[2] <= 56.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.06481481481481481, 0.6176470588235294, 'x[4] <= 41.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.05555555555555555, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.07407407407407407, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10185185185185185, 0.6176470588235294, 'x[6] <= 1.142\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.09259259259259259, 0.5588235294117647, 'x[7] <= 27.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.08333333333333333, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.10185185185185185, 0.5, 'x[0] <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09259259259259259, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1111111111111111, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1111111111111111, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06944444444444445, 0.7352941176470589, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.32233796296296297, 0.7941176470588235, 'x[2] <= 37.0\ngini = 0.379\nsamples = 134\nvalue = [100, 34]'),
#  Text(0.3130787037037037, 0.7352941176470589, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3315972222222222, 0.7352941176470589, 'x[5] <= 45.4\ngini = 0.349\nsamples = 129\nvalue = [100, 29]'),
#  Text(0.2789351851851852, 0.6764705882352942, 'x[5] <= 34.85\ngini = 0.324\nsamples = 123\nvalue = [98, 25]'),
#  Text(0.2013888888888889, 0.6176470588235294, 'x[3] <= 30.5\ngini = 0.43\nsamples = 48\nvalue = [33, 15]'),
#  Text(0.1574074074074074, 0.5588235294117647, 'x[5] <= 33.45\ngini = 0.293\nsamples = 28\nvalue = [23, 5]'),
#  Text(0.14814814814814814, 0.5, 'x[3] <= 8.0\ngini = 0.401\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.12962962962962962, 0.4411764705882353, 'x[1] <= 128.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12037037037037036, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1388888888888889, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16666666666666666, 0.4411764705882353, 'x[7] <= 24.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.1574074074074074, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.17592592592592593, 0.38235294117647056, 'x[2] <= 67.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.16666666666666666, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18518518518518517, 0.3235294117647059, 'x[6] <= 0.57\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.17592592592592593, 0.2647058823529412, 'x[0] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16666666666666666, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18518518518518517, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19444444444444445, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16666666666666666, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.24537037037037038, 0.5588235294117647, 'x[6] <= 0.478\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.2222222222222222, 0.5, 'x[7] <= 24.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.2037037037037037, 0.4411764705882353, 'x[5] <= 34.25\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.19444444444444445, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.21296296296296297, 0.38235294117647056, 'x[7] <= 23.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2037037037037037, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2222222222222222, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24074074074074073, 0.4411764705882353, 'x[5] <= 32.4\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.23148148148148148, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.25, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26851851851851855, 0.5, 'x[5] <= 32.7\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.25925925925925924, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2777777777777778, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.35648148148148145, 0.6176470588235294, 'x[2] <= 71.0\ngini = 0.231\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.3055555555555556, 0.5588235294117647, 'x[6] <= 0.139\ngini = 0.326\nsamples = 39\nvalue = [31.0, 8.0]'),
#  Text(0.2962962962962963, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3148148148148148, 0.5, 'x[1] <= 126.0\ngini = 0.301\nsamples = 38\nvalue = [31, 7]'),
#  Text(0.2962962962962963, 0.4411764705882353, 'x[0] <= 4.5\ngini = 0.219\nsamples = 32\nvalue = [28, 4]'),
#  Text(0.28703703703703703, 0.38235294117647056, 'x[6] <= 0.652\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(0.25925925925925924, 0.3235294117647059, 'x[7] <= 26.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.25, 0.2647058823529412, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.26851851851851855, 0.2647058823529412, 'x[6] <= 0.422\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25925925925925924, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2777777777777778, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3148148148148148, 0.3235294117647059, 'x[1] <= 112.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.3055555555555556, 0.2647058823529412, 'x[2] <= 61.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2962962962962963, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3148148148148148, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.32407407407407407, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3055555555555556, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.4411764705882353, 'x[6] <= 0.451\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.32407407407407407, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3425925925925926, 0.38235294117647056, 'x[3] <= 43.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3333333333333333, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.35185185185185186, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4074074074074074, 0.5588235294117647, 'x[3] <= 26.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.39814814814814814, 0.5, 'x[3] <= 24.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.3888888888888889, 0.4411764705882353, 'x[7] <= 21.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.37962962962962965, 0.38235294117647056, 'x[6] <= 0.626\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.37037037037037035, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3888888888888889, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39814814814814814, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4074074074074074, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4166666666666667, 0.5, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.38425925925925924, 0.6764705882352942, 'x[6] <= 0.464\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.375, 0.6176470588235294, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.39351851851851855, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.49952980324074076, 0.8529411764705882, 'x[1] <= 94.5\ngini = 0.481\nsamples = 243\nvalue = [145, 98]'),
#  Text(0.41550925925925924, 0.7941176470588235, 'x[6] <= 0.716\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(0.40625, 0.7352941176470589, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.42476851851851855, 0.7352941176470589, 'x[4] <= 28.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.41550925925925924, 0.6764705882352942, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4340277777777778, 0.6764705882352942, 'x[4] <= 168.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.42476851851851855, 0.6176470588235294, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.44328703703703703, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5835503472222222, 0.7941176470588235, 'x[5] <= 26.25\ngini = 0.498\nsamples = 202\nvalue = [108, 94]'),
#  Text(0.4895833333333333, 0.7352941176470589, 'x[5] <= 9.65\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.4710648148148148, 0.6764705882352942, 'x[7] <= 61.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4618055555555556, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.48032407407407407, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5081018518518519, 0.6764705882352942, 'x[7] <= 57.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.4988425925925926, 0.6176470588235294, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.5173611111111112, 0.6176470588235294, 'x[6] <= 0.343\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5081018518518519, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5266203703703703, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6775173611111112, 0.7352941176470589, 'x[6] <= 0.528\ngini = 0.499\nsamples = 175\nvalue = [84, 91]'),
#  Text(0.6189236111111112, 0.6764705882352942, 'x[5] <= 40.45\ngini = 0.49\nsamples = 114\nvalue = [65, 49]'),
#  Text(0.5850694444444444, 0.6176470588235294, 'x[3] <= 35.5\ngini = 0.48\nsamples = 105\nvalue = [63, 42]'),
#  Text(0.5451388888888888, 0.5588235294117647, 'x[2] <= 83.0\ngini = 0.495\nsamples = 91\nvalue = [50.0, 41.0]'),
#  Text(0.4930555555555556, 0.5, 'x[3] <= 6.0\ngini = 0.498\nsamples = 70\nvalue = [33, 37]'),
#  Text(0.42592592592592593, 0.4411764705882353, 'x[7] <= 30.0\ngini = 0.437\nsamples = 31\nvalue = [10, 21]'),
#  Text(0.4166666666666667, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4351851851851852, 0.38235294117647056, 'x[0] <= 9.0\ngini = 0.4\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.41203703703703703, 0.3235294117647059, 'x[6] <= 0.157\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.39351851851851855, 0.2647058823529412, 'x[0] <= 5.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.38425925925925924, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4027777777777778, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4305555555555556, 0.2647058823529412, 'x[5] <= 28.25\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(0.4212962962962963, 0.20588235294117646, 'x[5] <= 27.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.41203703703703703, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4305555555555556, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4398148148148148, 0.20588235294117646, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.4583333333333333, 0.3235294117647059, 'x[6] <= 0.265\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.44907407407407407, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4675925925925926, 0.2647058823529412, 'x[5] <= 32.8\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4583333333333333, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.47685185185185186, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5601851851851852, 0.4411764705882353, 'x[2] <= 81.0\ngini = 0.484\nsamples = 39\nvalue = [23, 16]'),
#  Text(0.5416666666666666, 0.38235294117647056, 'x[3] <= 21.5\ngini = 0.457\nsamples = 34\nvalue = [22, 12]'),
#  Text(0.5324074074074074, 0.3235294117647059, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5509259259259259, 0.3235294117647059, 'x[4] <= 187.0\ngini = 0.494\nsamples = 27\nvalue = [15, 12]'),
#  Text(0.5231481481481481, 0.2647058823529412, 'x[5] <= 31.85\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.49537037037037035, 0.20588235294117646, 'x[3] <= 26.5\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.4861111111111111, 0.14705882352941177, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5046296296296297, 0.14705882352941177, 'x[0] <= 2.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.49537037037037035, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5138888888888888, 0.08823529411764706, 'x[5] <= 27.55\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.5046296296296297, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5231481481481481, 0.029411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5509259259259259, 0.20588235294117646, 'x[7] <= 41.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.5416666666666666, 0.14705882352941177, 'x[2] <= 71.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5324074074074074, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5509259259259259, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5601851851851852, 0.14705882352941177, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5787037037037037, 0.2647058823529412, 'x[6] <= 0.203\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5694444444444444, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5879629629629629, 0.20588235294117646, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5787037037037037, 0.38235294117647056, 'x[5] <= 37.25\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5694444444444444, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5879629629629629, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5972222222222222, 0.5, 'x[4] <= 117.5\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.5879629629629629, 0.4411764705882353, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.6064814814814815, 0.4411764705882353, 'x[7] <= 38.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5972222222222222, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6157407407407407, 0.38235294117647056, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.625, 0.5588235294117647, 'x[1] <= 131.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.6157407407407407, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6342592592592593, 0.5, 'x[4] <= 44.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.625, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6435185185185185, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6527777777777778, 0.6176470588235294, 'x[1] <= 104.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.6435185185185185, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6620370370370371, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7361111111111112, 0.6764705882352942, 'x[3] <= 21.0\ngini = 0.429\nsamples = 61\nvalue = [19, 42]'),
#  Text(0.6990740740740741, 0.6176470588235294, 'x[7] <= 44.5\ngini = 0.488\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.6805555555555556, 0.5588235294117647, 'x[5] <= 42.35\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.6712962962962963, 0.5, 'x[5] <= 32.6\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.6620370370370371, 0.4411764705882353, 'x[6] <= 0.72\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6527777777777778, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6712962962962963, 0.38235294117647056, 'x[6] <= 0.765\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6620370370370371, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6805555555555556, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6805555555555556, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6898148148148148, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7175925925925926, 0.5588235294117647, 'x[0] <= 3.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.7083333333333334, 0.5, 'x[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6990740740740741, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7175925925925926, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7268518518518519, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7731481481481481, 0.6176470588235294, 'x[7] <= 59.0\ngini = 0.308\nsamples = 42\nvalue = [8, 34]'),
#  Text(0.7638888888888888, 0.5588235294117647, 'x[1] <= 152.5\ngini = 0.255\nsamples = 40\nvalue = [6, 34]'),
#  Text(0.7546296296296297, 0.5, 'x[2] <= 67.0\ngini = 0.188\nsamples = 38\nvalue = [4, 34]'),
#  Text(0.7361111111111112, 0.4411764705882353, 'x[5] <= 34.9\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.7268518518518519, 0.38235294117647056, 'x[2] <= 53.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7175925925925926, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7361111111111112, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7453703703703703, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7731481481481481, 0.4411764705882353, 'x[3] <= 54.5\ngini = 0.062\nsamples = 31\nvalue = [1, 30]'),
#  Text(0.7638888888888888, 0.38235294117647056, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.7824074074074074, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7731481481481481, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7824074074074074, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9409722222222222, 0.9117647058823529, 'x[7] <= 62.5\ngini = 0.312\nsamples = 93\nvalue = [18, 75]'),
#  Text(0.7920780888310185, 0.9411764705882353, '  False'),
#  Text(0.9004629629629629, 0.8529411764705882, 'x[6] <= 0.312\ngini = 0.27\nsamples = 87\nvalue = [14, 73]'),
#  Text(0.8472222222222222, 0.7941176470588235, 'x[6] <= 0.288\ngini = 0.412\nsamples = 31\nvalue = [9, 22]'),
#  Text(0.8379629629629629, 0.7352941176470589, 'x[7] <= 59.5\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(0.8287037037037037, 0.6764705882352942, 'x[1] <= 166.0\ngini = 0.302\nsamples = 27\nvalue = [5, 22]'),
#  Text(0.8101851851851852, 0.6176470588235294, 'x[6] <= 0.141\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.8009259259259259, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8194444444444444, 0.5588235294117647, 'x[7] <= 53.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.8101851851851852, 0.5, 'x[3] <= 35.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.8009259259259259, 0.4411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8194444444444444, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8287037037037037, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8472222222222222, 0.6176470588235294, 'x[0] <= 9.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.8379629629629629, 0.5588235294117647, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.8564814814814815, 0.5588235294117647, 'x[7] <= 37.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8472222222222222, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8657407407407407, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8472222222222222, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8564814814814815, 0.7352941176470589, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9537037037037037, 0.7941176470588235, 'x[6] <= 1.862\ngini = 0.163\nsamples = 56\nvalue = [5, 51]'),
#  Text(0.9444444444444444, 0.7352941176470589, 'x[5] <= 46.1\ngini = 0.135\nsamples = 55\nvalue = [4, 51]'),
#  Text(0.9351851851851852, 0.6764705882352942, 'x[2] <= 100.0\ngini = 0.105\nsamples = 54\nvalue = [3, 51]'),
#  Text(0.9120370370370371, 0.6176470588235294, 'x[3] <= 42.5\ngini = 0.074\nsamples = 52\nvalue = [2, 50]'),
#  Text(0.8935185185185185, 0.5588235294117647, 'x[7] <= 48.0\ngini = 0.04\nsamples = 49\nvalue = [1.0, 48.0]'),
#  Text(0.8842592592592593, 0.5, 'gini = 0.0\nsamples = 38\nvalue = [0, 38]'),
#  Text(0.9027777777777778, 0.5, 'x[1] <= 165.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.8935185185185185, 0.4411764705882353, 'x[5] <= 33.45\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8842592592592593, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9027777777777778, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9120370370370371, 0.4411764705882353, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9305555555555556, 0.5588235294117647, 'x[6] <= 0.458\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9212962962962963, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9398148148148148, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9583333333333334, 0.6176470588235294, 'x[0] <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9490740740740741, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9675925925925926, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9537037037037037, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9629629629629629, 0.7352941176470589, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9814814814814815, 0.8529411764705882, 'x[2] <= 85.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.9722222222222222, 0.7941176470588235, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9907407407407407, 0.7941176470588235, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
