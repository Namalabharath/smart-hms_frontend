# %%
import pandas as pd

# %%
df=pd.read_csv('Student_Performance.csv',usecols=['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced','Performance Index'])

# %%
df=df.drop_duplicates()

# %%
X=df.iloc[:,0:4]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
y_pred
# Out:
# array([27.51614192, 35.40466623, 79.66119562, ..., 61.47878551,
#        61.01158161, 62.51922854])

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print("r2_score:",r2_score(y_test_scaled,y_pred))
# Out:
# r2_score: -3268.1127610353506

# %%
print("mae:",mean_absolute_error(y_test_scaled,y_pred))
# Out:
# mae: 55.06462823625541
